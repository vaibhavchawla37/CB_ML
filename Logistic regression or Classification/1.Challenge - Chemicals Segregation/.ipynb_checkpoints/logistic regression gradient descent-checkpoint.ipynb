# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X_train = pd.read_csv('Logistic_X_Train.csv').values
X_test = pd.read_csv('Logistic_X_Test.csv')
y_train = pd.read_csv('Logistic_Y_Train.csv').values

# %%
np.unique(y_train,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([1509, 1491], dtype=int64))

# %%
(
X_train.shape,
X_test.shape,
y_train.shape,
)
# Out:
# ((3000, 3), (1000, 3), (3000, 1))

# %%
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap=plt.cm.Accent)

# %%
x_mean=X_train.mean(axis=0)
x_std=X_train.std(axis=0)

# %%
X_train=(X_train - x_mean)/x_std
X_test=(X_test - x_mean)/x_std

# %%
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap=plt.cm.Accent)

# %%
X_train.mean(axis=0),X_train.std(axis=0)
# Out:
# (array([ 6.51330841e-18, -3.07901852e-17, -9.47390314e-18]),
#  array([1., 1., 1.]))

# %%
def sigmoid(x):
    return 1.0/(1.0 + np.exp(-x))

def hypothesis(X,theta):
    return sigmoid(np.dot(X,theta))

def error(X,y,theta):
    hi = hypothesis(X,theta)
    e = -1*np.mean((y*np.log(hi)) + ((1 - y)*np.log(1-hi)))
    return e

def gradient(X,y,theta):
    hi = hypothesis(X,theta)
    grad = -np.dot(X.T,(y - hi))
    m = X.shape[0]
    return grad/m

def gradient_descent(X,y,lr=0.5,max_steps=500):
    n = X.shape[1]
    theta = np.zeros((n,1))
    error_list = []
    for i in range(max_steps):
        error_list.append(error(X,y,theta))
        grad = gradient(X,y,theta)
        theta = theta - lr*grad
    return theta,error_list

# %%
X_train=np.hstack((X_train,np.ones((X_train.shape[0],1))))
X_test=np.hstack((X_test,np.ones((X_test.shape[0],1))))
X_train.shape,X_test.shape
# Out:
# ((3000, 4), (1000, 4))

# %%
t,e = gradient_descent(X_train,y_train.reshape(-1,1))

# %%
np.array(e).shape
# Out:
# (500,)

# %%
plt.plot(e)

# %%
def predict(X,theta):
    h=hypothesis(X,theta)
    out = np.zeros((h.shape))
    out[h>=0.5]=1
    out= out.astype('int')
    return out

def acccuracy(actual,predict):
    actual = actual.astype('int')
    return  np.mean(actual==predict)

# %%
#ypred = predict (X_train,t)
ypred = hypothesis(X_train,t) 
ypred[ypred>=0.5]=1
ypred[ypred<0.5]=0
ypred=ypred.astype('int')
yt=y_train
yt=yt.astype('int')

# %%
np.mean(ypred==y_train)
# Out:
# 0.9946666666666667

# %%
x1 = np.arange(-3,4)
x2 = -(t[2] + t[1]*x1)/t[0]

# %%
ypred = predict (X_train,t)
acccuracy(y_train,ypred)
# Out:
# 0.9946666666666667

# %%
y_train.shape, ypred.shape
# Out:
# ((3000, 1), (3000, 1))

# %%
plt.scatter(X_train[:,0],X_train[:,1],X_train[:,2]*10,c=y_train,cmap=plt.cm.Accent)
plt.plot(x2,x1)
# Out:
# C:\Users\Vaibhav\anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
check=pd.read_csv('Chemicals.csv').values

# %%
y_x_test = predict(X_test,t) 
acccuracy(y_x_test,check)
# Out:
# 1.0
