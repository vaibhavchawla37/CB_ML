# %%
import cv2

# %%
img=cv2.imread('wallpaperflare.com_wallpaper(2).jpg')
img1=cv2.imread('wallpaperflare.com_wallpaper(3).jpg')

# img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

img11=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()
plt.imshow(img11)
plt.show()

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
cv2.namedWindow("night city", cv2.WINDOW_NORMAL)
cv2.imshow('night city',img)

cv2.waitKey(0)
cv2.destroyAllWindows()
